# %% [markdown]
# # 2. List of different approaches of how such game can be re-created. You can also use consider the other type of the data than we are providing

# %% [markdown]
# Multiple method could be used:
#
# 1) data augmentation, noise injection to norm and repeat other param
# 2) Use markov chain to model action, then generate size of list using normal distribution, and generate norm value using normal distribution
# 3) Use markov chain to model action, then generate size of list using normal distribution, and generate norm value using GAN
# 4) Use markov chain to model action, then generate size of list using normal distribution, and generate norm value using LSTM

# %% [markdown]
# # Please fully describe at least one approach you would choose (in jupyter notebook or some additional pdf):
# ## a. The chosen architecture/algorithm. Why the decision was made, why it makes sense, and what kind of input it assumes. If the mathematical theory for the chosen approach is too complicated, the flow chart is enough.
# ## b. The pre- / post-processing of the data

# %% [markdown]
# A)
#
#
# ## Summary of Solution:
#
# I employed a multi-pronged approach to model and generate the desired sequences:
#
# ### 1. **Markov Chain for Action Sequencing**:
# I utilized a Markov chain to model and generate action sequences. This approach ensures that the action labels are generated in a meaningful and coherent order, mimicking real-world scenarios.
#
# ### 2. **Normal Distribution for List Size Determination**:
# Given the significance of maintaining the gait length, I chose to model the size of the list using a normal distribution. This approach ensures that the generated lengths closely resemble the real-world data distribution.
#
# ### 3. **LSTM for Norm Value Generation**:
# For the generation of norm values, I deployed an LSTM (Long Short-Term Memory) model, which is adept at handling and generating sequences. The LSTM architecture comprised two layers:
# - A layer for norm values: This captures the sequence of previous values.
# - A layer for labels: Recognizing that the norm values are influenced by actions, this layer ensures that the generated norm values are consistent with the associated action labels.
#
# ## Reflection:
# Upon the completion of this model, I believe that while the LSTM approach has its strengths, there might be areas of potential refinement. Some generated values appear unconventional, indicating the possibility of overfitting or over-complexity. We can delve deeper into these aspects and discuss potential improvements during our interview.

# %% [markdown]
# B)
#
#
#
# Proper preprocessing of the data was essential to prepare it for modeling. The following steps were undertaken:
# - **Encoding Labels**: The action labels were encoded to numerical values, making them suitable for model processing.
# - **Standardizing Norm Values**: To stabilize the LSTM and ensure consistent input, the norm values were standardized. This standardization helps in ensuring smoother training and better performance of the LSTM model.

# %% [markdown]
# # 5. Parametrize your fitted algorithm/program for recreating the game in the following way:
#
# Bonus: It will be possible to generate game with specific type of play - e.g
# more attacking game (there will be more passes, shots), defending game
# (more tackles, interceptions, etc.), or just normal game.

# %% [markdown]
# ##  1. Adjusting the Markov Chain for Specific Actions:
# To generate specific actions with greater or lesser frequency, the transition probabilities in the Markov chain can be fine-tuned. For instance:
#
# ### For a Striker:
# After observing that the probability of a shot post a dribble is 0.09, one could reduce the probabilities of other subsequent actions post-dribble, transferring that proportion to the shooting probability. It's crucial to strike a balance to avoid excessive shooting actions, which may deviate from realistic play.
#
# ### For a Defender:
# To simulate defensive actions like tackling with greater frequency, the probabilities of actions like tackling could be increased post certain preceding actions.
#
# ## 2. Balancing the Coefficients:
# The key challenge lies in adjusting the coefficients in a manner that the generated sequences remain realistic. While emphasizing a specific action, care should be taken to ensure that the player doesn't overly rely on that singular action, as this would distort the authenticity of the gameplay.

# %%
# Import necessary libraries
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

import numpy as np
from keras.models import Sequential, Model
from keras.layers import LSTM, Dense, Embedding, Concatenate, Input, Flatten, Reshape, RepeatVector, Dropout
from keras.layers import concatenate
from keras.optimizers import Adam

from keras.callbacks import Callback

import re
from keras.models import load_model




# Define the file path. Replace with the actual path to the file if different.
file_path = 'data/match_1.json'
# Load the JSON file into a pandas DataFrame with records orientation.
match_1_data = pd.read_json(file_path, orient='records')

file_path = 'data/match_2.json'
match_2_data = pd.read_json(file_path, orient='records')


# Combiner les données des deux matches
data = pd.concat([match_1_data, match_2_data], ignore_index=True)
data
# Out:
#      label                                               norm
# 0     walk  [23.177037336396975, 23.361525285249378, 21.53...
# 1     walk  [20.998214383911275, 19.182798059840767, 18.27...
# 2     walk  [21.95259682019565, 20.62720484424047, 22.5554...
# 3     walk  [19.39209748358647, 19.30460665293087, 18.9787...
# 4     rest  [22.069263037713093, 19.672270483203395, 19.88...
# ...    ...                                                ...
# 1182  walk  [23.337305769963503, 20.210987911153104, 25.06...
# 1183  walk  [22.470322813933603, 22.552427730975246, 23.84...
# 1184  walk  [43.833612705797144, 46.18045998580312, 37.492...
# 1185  walk  [30.927599255773355, 31.26358258808756, 28.286...
# 1186  walk  [30.94168559492879, 47.060036178960765, 37.195...
#
# [1187 rows x 2 columns]

# %%
def compute_transition_frequencies(data):
    """
    Compute the frequency of transitions between different actions in the data.
    
    Args:
    - data (DataFrame): The dataset containing labeled sequences of actions.

    Returns:
    - matrix (dict): A dictionary representing the frequency of transitions 
                     between different actions.
    """
    matrix = {}  # Initialize an empty dictionary to hold transition frequencies.
    
    # Loop through each row of the data except the last one
    for i in range(len(data)-1):
        # Get the current action from the 'label' column
        current_action = data.iloc[i]['label']
        # Get the next action from the 'label' column
        next_action = data.iloc[i+1]['label']
        
        # Check if the current action is already in the matrix
        if current_action not in matrix:
            matrix[current_action] = {}  # If not, initialize it with an empty dictionary.
        
        # Check if the next action is already a key under the current action
        if next_action not in matrix[current_action]:
            matrix[current_action][next_action] = 1  # If not, initialize it with a count of 1.
        else:
            matrix[current_action][next_action] += 1  # If yes, increment the count.
    
    # Loop to normalize the transition counts to get transition probabilities
    for current_action, transitions in matrix.items():
        # Calculate the total count of transitions from the current action
        total = sum(transitions.values())
        # Normalize each count by the total
        for next_action, count in transitions.items():
            matrix[current_action][next_action] = count / total
    
    return matrix


def generate_actions(transitions, n):
    """
    Generate a sequence of actions based on the transition probabilities.

    Args:
    - transitions (dict): A dictionary representing the transition probabilities.
    - n (int): Length of the sequence to be generated.

    Returns:
    - sequence (list): Generated sequence of actions.
    """
    # Start with the "walk" action
    current_action = "walk"
    sequence = [current_action]

    for _ in range(n-1):
        # Check if there are possible transitions from the current action
        if current_action in transitions and transitions[current_action]:
            next_actions = list(transitions[current_action].keys())
            next_probs = list(transitions[current_action].values())
            current_action = np.random.choice(next_actions, p=next_probs)
        else:
            # If no possible transitions, choose a random action (excluding "walk" to avoid repetition)
            current_action = np.random.choice([action for action in transitions.keys() if action != "walk"])
        sequence.append(current_action)

    return sequence

# %%
def get_label_specific_stats(data):
    """
    Compute the mean and standard deviation of lengths for each label.

    Args:
    - data (DataFrame): The dataset containing sequences and their labels.

    Returns:
    - stats (dict): A dictionary where keys are labels and values are 
                    (mean, std) tuples for that label's lengths.
    """
    # Compute lengths for each row and then group by the label
    lengths_by_label = data.groupby('label')['norm'].apply(lambda x: x.apply(len))
    
    means = lengths_by_label.groupby('label').mean()
    stds = lengths_by_label.groupby('label').std()
    
    return {label: (mean, std) for label, mean, std in zip(means.index, means, stds)}

def generate_length_for_action(action, stats):
    """Generate a sequence length for a given action based on stored statistics."""
    mean, std = stats[action]
    return int(abs(np.random.normal(mean, std)))

# %%
# Use the build_transition_matrix function to get transition probabilities
transitions = compute_transition_frequencies(data)

stats = get_label_specific_stats(data)

# %%
# # Use the build_transition_matrix function to get transition probabilities
# transitions = compute_transition_frequencies(data)
# # Generate actions for 10 minutes
# new_actions = generate_actions(transitions, 5)  # Adjust this based on your data


# stats = get_label_specific_stats(data)
# print(new_actions)
# print(stats)
# # Generate new sequences
# new_sequences = []
# for action in new_actions:

#     length = generate_length_for_action(action, stats)
#     print(length)
#     new_sequences.append({"label": action, "norm": [0] * length})

# print(new_sequences)

# %% [markdown]
# # Modeling part

# %%
num_labels = len(set(data['label']))

# Define the input shapes
sequence_length = 20

# Sequence input
sequence_input = Input(shape=(sequence_length, 1), name='sequence_input')

# Label input and embedding
label_input = Input(shape=(1,), name='label_input')
label_embedding = Embedding(input_dim=num_labels, output_dim=8)(label_input)  # increased embedding size
label_embedding = Flatten()(label_embedding)

# Expand dimensions and tile the embedding to match the sequence length
label_embedding = RepeatVector(sequence_length)(label_embedding)

# Concatenate sequence and label embedding
merged_input = concatenate([sequence_input, label_embedding])

# LSTM layers with dropout
lstm_out = LSTM(32, return_sequences=True, dropout=0.0)(merged_input)  # adjusted LSTM units and dropout
lstm_out = LSTM(16, dropout=0.0)(lstm_out)  # adjusted LSTM units and dropout

# Dense layer to predict the next value in the sequence
output = Dense(1, activation='linear')(lstm_out)

# Compile the model with the default learning rate
optimizer = Adam(learning_rate=0.01)
model = Model(inputs=[sequence_input, label_input], outputs=output)
model.compile(optimizer=optimizer, loss='mse')

# %%
sequences = data['norm'].tolist()

# Compute the mean and standard deviation of your sequences
all_values = [item for sublist in sequences for item in sublist]
mean = np.mean(all_values)
std = np.std(all_values)

# Standardize the sequences
sequences = [(np.array(seq) - mean) / std for seq in sequences]
sequences = [seq.tolist() for seq in sequences]

labels = data['label'].tolist()

# Convert labels to unique integers for embedding
label_to_int = {label: i for i, label in enumerate(set(labels))}
encoded_labels = [label_to_int[label] for label in labels]

def prepare_training_data(sequences, encoded_labels, sequence_length):
    X_seq, X_label, Y = [], [], []
    for seq, label in zip(sequences, encoded_labels):
        for i in range(1, min(len(seq), sequence_length)):
            padded_seq = seq[:i] + [0] * (sequence_length - i)
            if len(padded_seq) != sequence_length:
                print(f"Unexpected sequence length. Before padding: {len(seq[:i])}, After padding: {len(padded_seq)}")
                continue
            X_seq.append(padded_seq)
            X_label.append(label)
            Y.append(seq[i])
    X_seq = np.array(X_seq)
    X_label = np.array(X_label)
    Y = np.array(Y)
    return X_seq, X_label, Y

X_seq, X_label, Y = prepare_training_data(sequences, encoded_labels, sequence_length)

# %%
class PredictSamples(Callback):
    def __init__(self, X_seq_sample, X_label_sample, Y_sample):
        super(PredictSamples, self).__init__()
        self.X_seq_sample = X_seq_sample
        self.X_label_sample = X_label_sample
        self.Y_sample = Y_sample

    def on_epoch_end(self, epoch, logs=None):
        predictions = self.model.predict([self.X_seq_sample, self.X_label_sample])
        print("\nSample predictions after epoch {}:".format(epoch+1))
        for actual, predicted in zip(self.Y_sample, predictions):
            print("Actual: {:.3f}, Predicted: {:.3f}".format(actual, predicted[0]))
        print("----------------------")

# Choose a small sample of your data
sample_size = 10
X_seq_sample = X_seq[:sample_size]
X_label_sample = X_label[:sample_size]
Y_sample = Y[:sample_size]

# Use the custom callback during training
sample_callback = PredictSamples(X_seq_sample, X_label_sample, Y_sample)

# %%
# # When training, include this callback
# history = model.fit([X_seq, X_label], Y, epochs=15, batch_size=32, validation_split=0.2, callbacks=[sample_callback])


# # Plotting the training and validation loss
# plt.figure(figsize=(8, 4))
# plt.plot(history.history['loss'], label='Training Loss')
# plt.plot(history.history['val_loss'], label='Validation Loss')
# plt.title('Training and Validation MSE')
# plt.xlabel('Epoch')
# plt.ylabel('MSE Value')
# plt.legend()
# plt.show()

# %%
# save my model:
# model.save('model/lstm_norm_values.keras')

# %% [markdown]
# # Prediction part

# %%
def warmup_sequence(model, sequence_length, action):
    # Initialize a zero sequence for warmup
    current_sequence = np.zeros(sequence_length).reshape(1, sequence_length)
    warmup_output = []
    
    # Get the encoded label for the action
    encoded_label = get_encoded_label_for_action(action)
    encoded_label_array = np.array([encoded_label]).reshape(1, -1)
    
    for _ in range(sequence_length):
        next_value = model.predict([current_sequence, encoded_label_array])
        warmup_output.append(next_value[0][0])
        current_sequence = np.append(current_sequence[0, 1:], next_value[0]).reshape(1, sequence_length)
    
    return np.array(warmup_output)

def fill_table_with_sequence(model, action_table_length, sequence_length, action, last_20_values):
    # Create a zero-filled action table based on the provided length
    action_table = np.zeros(action_table_length)
    
    # Check if the last_20_values are all zeros (first action scenario)
    if np.all(last_20_values == 0):
        warmup_output = warmup_sequence(model, sequence_length, action)
        action_table[:min(len(warmup_output), action_table_length)] = warmup_output[:action_table_length]
        current_sequence = warmup_output.reshape(1, sequence_length)
        start_idx = len(warmup_output)
    elif action_table_length >= sequence_length:
        current_sequence = last_20_values.reshape(1, sequence_length)
        action_table[:sequence_length] = last_20_values
        start_idx = sequence_length
    else:  # In case action_table_length is less than sequence_length
        assign_length = min(sequence_length, action_table_length)
        action_table[:assign_length] = last_20_values[-assign_length:]
        current_sequence = last_20_values[-sequence_length:].reshape(1, sequence_length)
        start_idx = assign_length

    # Get the encoded label for the action
    encoded_label = get_encoded_label_for_action(action)
    encoded_label_array = np.array([encoded_label]).reshape(1, -1)
    
    for i in range(start_idx, action_table_length):
        # Predict the next value using the LSTM model
        next_value = model.predict([current_sequence, encoded_label_array])
        action_table[i] = next_value[0][0]
        current_sequence = np.append(current_sequence[0, 1:], next_value[0]).reshape(1, sequence_length)

    return action_table, action_table[-sequence_length:]


def get_encoded_label_for_action(action):
    return label_to_int[action]

# %%
def generateData(time_in_minutes, transitions, stats, model, sequence_length, last_20_values):
    # 50 samples/second * 60 seconds/minute = 3000 samples/minute
    total_samples_needed = time_in_minutes * 3000

    # Estimate average action length using stats
    avg_action_length = np.mean([mean for mean, std in stats.values()])

    # Estimate the number of actions needed
    num_actions = int(total_samples_needed / avg_action_length)

    # Generate action list
    action_list = generate_actions(transitions, num_actions)
    print("Number of action to generate "+str(len(action_list)))
    # Create a dataframe to store the results
    df = pd.DataFrame(columns=['label', 'norm'])
    
    for index, action in enumerate(action_list):
        print("Generating action number: "+str(index))
        action_table_length = generate_length_for_action(action, stats)
        
        # Ensure the first action has a minimum length of 20
        if index == 0 and action_table_length < 20:
            action_table_length = 20

        filled_table, new_last_values = fill_table_with_sequence(model, action_table_length, sequence_length, action, last_20_values)
        
        # Update last_20_values
        if len(filled_table) < sequence_length:
            last_20_values = np.concatenate((last_20_values[len(filled_table):], filled_table))
        else:
            last_20_values = new_last_values
        
        # Append to dataframe
        df.loc[len(df)] = [action, filled_table.tolist()]  # store the filled_table as a list

    # Return the dataframe
    return df

# %%
def get_next_match_number(directory_path):
    # List all files in the directory
    files = os.listdir(directory_path)
    
    # Regular expression pattern to match our file names and extract the number
    pattern = re.compile(r'output_Match_(\d+)')
    
    # Extract all match numbers from filenames
    match_numbers = [int(match.group(1)) for file in files for match in [pattern.search(file)] if match]
    
    # Return the next match number
    if match_numbers:
        return max(match_numbers) + 1
    else:
        return 1

# %%
import argparse

def main(time_in_minutes):
    last_20_values = np.zeros(20)
    model_path = "model/lstm_norm_values.keras"
    model = load_model(model_path)
    df_result = generateData(time_in_minutes, transitions, stats, model, sequence_length, last_20_values)

    df = df_result
    # mean and std are previously defined
    for idx, row in df.iterrows():
        norm_array = np.array(row['norm'])
        reversed_norm = (norm_array * std) + mean
        df.at[idx, 'norm'] = reversed_norm.tolist()


    def get_next_match_number(directory_path):
        files = os.listdir(directory_path)
        pattern = re.compile(r'output_Match_(\d+)')
        match_numbers = [int(match.group(1)) for file in files for match in [pattern.search(file)] if match]
        if match_numbers:
            return max(match_numbers) + 1
        else:
            return 1



    # Convert the dataframe to a list of dictionaries
    formatted_data = df.to_dict(orient='records')
    
    # Save to JSON file
    directory_path = "generatedData/"
    next_match_number = get_next_match_number(directory_path)
    filename = f"generatedData/output_Match_{next_match_number}_{time_in_minutes}_Min.json"
    with open(filename, 'w') as f:
        json.dump(formatted_data, f)

if __name__ == "__main__":
    parser = argparse.ArgumentParser(description='Generate data for a specified time duration.')
    parser.add_argument('time_in_minutes', type=int, help='Duration for which data should be generated (in minutes).')
    args = parser.parse_args()
    main(args.time_in_minutes)
# Out:
# usage: ipykernel_launcher.py [-h] time_in_minutes
# ipykernel_launcher.py: error: argument time_in_minutes: invalid int value: 'C:\\Users\\rabah\\AppData\\Roaming\\jupyter\\runtime\\kernel-29c2d21e-68e6-4209-9f54-952dbf77647d.json'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2529, in ArgumentParser._get_value(self, action, arg_string)
#    2528 try:
# -> 2529     result = type_func(arg_string)
#    2531 # ArgumentTypeErrors indicate errors
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\rabah\\AppData\\Roaming\\jupyter\\runtime\\kernel-29c2d21e-68e6-4209-9f54-952dbf77647d.json'
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:1902, in ArgumentParser.parse_known_args(self, args, namespace)
#    1901 try:
# -> 1902     namespace, args = self._parse_known_args(args, namespace)
#    1903 except ArgumentError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2117, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2116 # consume any positionals following the last Optional
# -> 2117 stop_index = consume_positionals(start_index)
#    2119 # if we didn't consume all the argument strings, there were extras
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2073, in ArgumentParser._parse_known_args.<locals>.consume_positionals(start_index)
#    2072     start_index += arg_count
# -> 2073     take_action(action, args)
#    2075 # slice off the Positionals that we just parsed and return the
#    2076 # index at which the Positionals' string args stopped
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:1962, in ArgumentParser._parse_known_args.<locals>.take_action(action, argument_strings, option_string)
#    1961 seen_actions.add(action)
# -> 1962 argument_values = self._get_values(action, argument_strings)
#    1964 # error if this argument is not allowed with other previously
#    1965 # seen arguments, assuming that actions that use the default
#    1966 # value don't really count as "present"
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2496, in ArgumentParser._get_values(self, action, arg_strings)
#    2495 arg_string, = arg_strings
# -> 2496 value = self._get_value(action, arg_string)
#    2497 self._check_value(action, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2542, in ArgumentParser._get_value(self, action, arg_string)
#    2541     msg = _('invalid %(type)s value: %(value)r')
# -> 2542     raise ArgumentError(action, msg % args)
#    2544 # return the converted value
#
# ArgumentError: argument time_in_minutes: invalid int value: 'C:\\Users\\rabah\\AppData\\Roaming\\jupyter\\runtime\\kernel-29c2d21e-68e6-4209-9f54-952dbf77647d.json'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[19], line 34
#      33 parser.add_argument('time_in_minutes', type=int, help='Duration for which data should be generated (in minutes).')
# ---> 34 args = parser.parse_args()
#      35 main(args.time_in_minutes)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:1869, in ArgumentParser.parse_args(self, args, namespace)
#    1868 def parse_args(self, args=None, namespace=None):
# -> 1869     args, argv = self.parse_known_args(args, namespace)
#    1870     if argv:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:1904, in ArgumentParser.parse_known_args(self, args, namespace)
#    1903     except ArgumentError as err:
# -> 1904         self.error(str(err))
#    1905 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2630, in ArgumentParser.error(self, message)
#    2629 args = {'prog': self.prog, 'message': message}
# -> 2630 self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\argparse.py:2617, in ArgumentParser.exit(self, status, message)
#    2616     self._print_message(message, _sys.stderr)
# -> 2617 _sys.exit(status)
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:2097, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2094 if exception_only:
#    2095     stb = ['An exception has occurred, use %tb to see '
#    2096            'the full traceback.\n']
# -> 2097     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2098                                                      value))
#    2099 else:
#    2101     def contains_exceptiongroup(val):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# If you want to generate from here

# %%
# time_in_minutes = 1

# %%
# # Usage
# last_20_values = np.zeros(20)



# model_path = "model/lstm_norm_values.keras"
# model = load_model(model_path)

# df_result = generateData(time_in_minutes, transitions, stats, model, sequence_length, last_20_values)
# print(df_result)

# df=df_result
# # mean and std are previously defined
# for idx, row in df.iterrows():
#     # Convert the list to numpy array
#     norm_array = np.array(row['norm'])
    
#     # Reverse the standardization
#     reversed_norm = (norm_array * std) + mean
    
#     # Update the 'norm' column in the dataframe
#     df.at[idx, 'norm'] = reversed_norm.tolist()




# # Display the updated dataframe
# print(df)





# # Convert the dataframe to a list of dictionaries
# formatted_data = df.to_dict(orient='records')

# # Save to JSON file
# directory_path = "generatedData/"
# next_match_number = get_next_match_number(directory_path)
# filename = f"generatedData/output_Match_{next_match_number}_{time_in_minutes}_Min.json"
# with open(filename, 'w') as f:
#     json.dump(formatted_data, f)
# Out:
# Number of action to generate 48
# Generating action number: 0
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 1
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Generating action number: 2
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 9ms/step
# Generating action number: 3
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# Generating action number: 4
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# Generating action number: 5
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# Generating action number: 6
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# Generating action number: 7
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Generating action number: 8
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# Generating action number: 9
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 10
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# Generating action number: 11
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# Generating action number: 12
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# Generating action number: 13
# Generating action number: 14
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# Generating action number: 15
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# Generating action number: 16
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# Generating action number: 17
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 18
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# Generating action number: 19
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Generating action number: 20
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# Generating action number: 21
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# Generating action number: 22
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 23
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# Generating action number: 24
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# Generating action number: 25
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# Generating action number: 26
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 36ms/step
# Generating action number: 27
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# Generating action number: 28
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# Generating action number: 29
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# Generating action number: 30
# Generating action number: 31
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Generating action number: 32
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# Generating action number: 33
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# Generating action number: 34
# 1/1 [==============================] - 0s 20ms/step
# Generating action number: 35
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 36
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# Generating action number: 37
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 36ms/step
# Generating action number: 38
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# ...
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# Generating action number: 41
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# Generating action number: 42
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# Generating action number: 43
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# Generating action number: 44
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# Generating action number: 45
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# Generating action number: 46
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# Generating action number: 47
#       label                                               norm
# 0      walk  [-0.09487688541412354, 0.2344033122062683, -0....
# 1      walk  [0.391987681388855, 0.14212477207183838, 0.211...
# 2       run  [0.11512267589569092, 0.26545631885528564, 0.4...
# 3       run  [0.1288543939590454, 0.17972087860107422, 0.14...
# 4      walk  [0.09872746467590332, 0.15723270177841187, 0.1...
# 5      walk  [0.31034591794013977, 0.27697423100471497, 0.1...
# 6       run  [0.22500672936439514, 0.19014346599578857, 0.1...
# 7       run  [0.2538900673389435, 0.15367978811264038, 0.16...
# 8       run  [0.18550187349319458, 0.15488815307617188, 0.2...
# 9       run  [0.1999639868736267, 0.44310253858566284, 0.23...
# 10      run  [0.07996565103530884, 0.04066038131713867, 0.1...
# 11      run  [0.20029646158218384, 0.2600240409374237, 0.54...
# 12     walk  [0.4053214192390442, 0.4793124198913574, 0.723...
# 13     walk  [1.4761781692504883, 2.1574010848999023, 1.499...
# 14     walk  [1.5191165208816528, 1.4761781692504883, 2.157...
# 15     walk  [2.302826166152954, 1.519637107849121, 2.30286...
# 16      run  [2.3029088973999023, 1.5196895599365234, 2.302...
# 17      run  [1.5221542119979858, 1.7961344718933105, 1.557...
# 18      run  [1.4239153861999512, 1.5571579933166504, 1.462...
# 19      run  [1.4780137538909912, 1.4693514108657837, 1.479...
# 20      run  [1.4736464023590088, 1.4684605598449707, 1.472...
# 21      run  [1.4710803031921387, 1.470388650894165, 1.4710...
# 22     walk  [1.4709718227386475, 1.4704898595809937, 1.470...
# 23     walk  [1.5878251791000366, 2.2352874279022217, 1.565...
# 24     walk  [2.3028953075408936, 1.5197553634643555, 2.302...
# 25     walk  [2.3029093742370605, 1.5196900367736816, 2.302...
# 26     walk  [1.5196900367736816, 2.3029091358184814, 1.519...
# 27     walk  [2.3029093742370605, 1.5196900367736816, 2.302...
# 28     walk  [2.3029093742370605, 1.5196902751922607, 2.302...
# 29      run  [2.3029091358184814, 1.5196897983551025, 2.302...
# 30      run  [1.5221538543701172, 1.7961347103118896, 1.557...
# 31      run  [1.4219433069229126, 1.5975042581558228, 1.423...
# 32      run  [1.880619764328003, 1.4219433069229126, 1.5975...
# 33      run  [1.4700343608856201, 1.4713764190673828, 1.470...
# 34      run  [1.470829963684082, 1.4706227779388428, 1.4708...
# 35      run  [1.4706227779388428, 1.4708179235458374, 1.470...
# 36   tackle  [1.4707753658294678, 1.4706742763519287, 1.470...
# 37  dribble  [1.7128219604492188, 1.70784592628479, 1.72039...
# 38    cross  [1.7475271224975586, 1.7376091480255127, 1.751...
# 39     pass  [1.7143354415893555, 1.8032970428466797, 1.663...
# 40      run  [1.3419804573059082, 2.4041061401367188, 1.162...
# 41     walk  [1.5331661701202393, 1.5214571952819824, 1.511...
# 42     walk  [1.6602613925933838, 2.143662929534912, 1.6259...
# 43     walk  [1.5263333320617676, 2.300351619720459, 1.5242...
# 44      run  [1.5196902751922607, 2.3029091358184814, 1.519...
# 45      run  [1.515183448791504, 1.8933990001678467, 1.4669...
# 46      run  [1.532238245010376, 1.6633048057556152, 1.5493...
# 47      run  [1.470145344734192, 1.4712743759155273, 1.4701...
#       label                                               norm
# 0      walk  [37.573015156041215, 51.02365711863295, 25.972...
# 1      walk  [57.460761275195146, 47.25420601544276, 50.097...
# 2       run  [46.151207625228196, 52.29212961505508, 61.138...
# 3       run  [46.712129370708816, 48.789955118385144, 47.37...
# 4      walk  [45.48148585752973, 47.8713441086159, 49.36326...
# 5      walk  [54.12580783044153, 52.7626204420108, 49.32550...
# 6       run  [50.63981966836642, 49.21570343967273, 48.5167...
# 7       run  [51.81966419162578, 47.726212485191084, 48.136...
# 8       run  [49.0261007871603, 47.77557252749566, 50.82827...
# 9       run  [49.61685817405563, 59.5487326992037, 51.20501...
# 10      run  [44.71509164472184, 43.10952558261782, 48.2124...
# 11      run  [49.630439307384435, 52.07022855376293, 63.769...
# 12     walk  [58.005426077822335, 61.02785641350713, 71.007...
# 13     walk  [101.74844749763373, 129.57546412763605, 102.6...
# 14     walk  [103.50241994550163, 101.74844749763373, 129.5...
# 15     walk  [135.51587814114635, 103.52368520518141, 135.5...
# 16      run  [135.51925759848953, 103.52582780061513, 135.5...
# 17      run  [103.62650543832511, 114.81822120897192, 105.0...
# 18      run  [99.61358488560447, 105.05636163149042, 101.19...
# 19      run  [101.82342859874416, 101.46958383239857, 101.8...
# 20      run  [101.6450283116756, 101.43319379677068, 101.61...
# 21      run  [101.5402066996154, 101.5119536571006, 101.538...
# 22     walk  [101.53577542269562, 101.51608789238068, 101.5...
# 23     walk  [106.30907387763693, 132.75701382625337, 105.4...
# 24     walk  [135.5187024714908, 103.52851578397745, 135.51...
# 25     walk  [135.51927707662983, 103.52584727875544, 135.5...
# 26     walk  [103.52584727875544, 135.51926733755968, 103.5...
# 27     walk  [135.51927707662983, 103.52584727875544, 135.5...
# 28     walk  [135.51927707662983, 103.52585701782559, 135.5...
# 29      run  [135.51926733755968, 103.52583753968528, 135.5...
# 30      run  [103.62649082971987, 114.8182309480421, 105.05...
# 31      run  [99.53302816683126, 106.70445090865138, 99.613...
# 32      run  [118.26932889129293, 99.53302816683126, 106.70...
# 33      run  [101.49748139885276, 101.5523026247458, 101.50...
# 34      run  [101.52998067595439, 101.52151742399116, 101.5...
# 35      run  [101.52151742399116, 101.52948885291165, 101.5...
# 36   tackle  [101.52775042888929, 101.52362106314428, 101.5...
# 37  dribble  [111.41502001273514, 111.21175587956515, 111.7...
# 38    cross  [112.83267802053342, 112.42754244122534, 112.9...
# 39     pass  [111.47684363006843, 115.11080235451806, 109.4...
# 40      run  [96.26665603671358, 139.6530254032077, 88.9239...
# 41     walk  [104.0763287410317, 103.59803326673187, 103.18...
# 42     walk  [109.26799330208436, 129.0142794272613, 107.86...
# 43     walk  [103.79721672950762, 135.414796332025, 103.711...
# 44      run  [103.52585701782559, 135.51926733755968, 103.5...
# 45      run  [103.34175937471733, 118.791343051511, 101.371...
# 46      run  [104.03842427999497, 109.39231253259155, 104.7...
# 47      run  [101.50201493600913, 101.5481343027202, 101.50...
